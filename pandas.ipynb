# %% [markdown]
# <a href="https://colab.research.google.com/github/shahid07-ux/python-basics/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/Student_performance_data _.csv")
print(df.head())
# Out:
#    StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0       1001   17       1          0                  2        19.833723
# 1       1002   18       0          0                  1        15.408756
# 2       1003   15       0          2                  3         4.210570
# 3       1004   17       1          0                  3        10.028829
# 4       1005   17       1          0                  2         4.672495
#
#    Absences  Tutoring  ParentalSupport  Extracurricular  Sports  Music  \
# 0         7         1                2                0       0      1
# 1         0         0                1                0       0      0
# 2        26         0                2                0       0      0
# 3        14         0                3                1       0      0
# 4        17         1                3                0       0      0
#
#    Volunteering       GPA  GradeClass
# 0             0  2.929196         2.0
# ...

# %%
print(df.info())
print(df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2392 entries, 0 to 2391
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   StudentID          2392 non-null   int64
#  1   Age                2392 non-null   int64
#  2   Gender             2392 non-null   int64
#  3   Ethnicity          2392 non-null   int64
#  4   ParentalEducation  2392 non-null   int64
#  5   StudyTimeWeekly    2392 non-null   float64
#  6   Absences           2392 non-null   int64
#  7   Tutoring           2392 non-null   int64
#  8   ParentalSupport    2392 non-null   int64
#  9   Extracurricular    2392 non-null   int64
#  10  Sports             2392 non-null   int64
#  11  Music              2392 non-null   int64
#  12  Volunteering       2392 non-null   int64
#  13  GPA                2392 non-null   float64
#  14  GradeClass         2392 non-null   float64
# dtypes: float64(3), int64(12)
# memory usage: 280.4 KB
# None
# ...

# %%
avg_gpa = df["GPA"].mean()
print("average GPA:",avg_gpa)
# Out:
# average GPA: 1.9061863027265407

# %%
top_student = df.loc[df["GPA"].idxmax()]
print("top performance:")
print(top_student)
# Out:
# top performance:
# StudentID            1045.000000
# Age                    18.000000
# Gender                  1.000000
# Ethnicity               0.000000
# ParentalEducation       1.000000
# StudyTimeWeekly        18.921512
# Absences                1.000000
# Tutoring                1.000000
# ParentalSupport         3.000000
# Extracurricular         1.000000
# Sports                  1.000000
# Music                   0.000000
# Volunteering            0.000000
# GPA                     4.000000
# GradeClass              0.000000
# Name: 44, dtype: float64

# %%
df ["result"]=df["GPA"].apply(lambda x: "pass"if x>=2.5 else "fail")
pass_percentage = (df["result"] == "pass").mean()* 100
print("pass percentage:",pass_percentage)
# Out:
# pass percentage: 29.515050167224082

# %%
#student with high study time
high_study = df[df["StudyTimeWeekly"] > 10]
print("students who study more than 10 hours:")
print(high_study.head())
# Out:
# students who study more than 10 hours:
#    StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0       1001   17       1          0                  2        19.833723
# 1       1002   18       0          0                  1        15.408756
# 3       1004   17       1          0                  3        10.028829
# 6       1007   15       0          1                  1        15.601680
# 7       1008   15       1          1                  4        15.424496
#
#    Absences  Tutoring  ParentalSupport  Extracurricular  Sports  Music  \
# 0         7         1                2                0       0      1
# 1         0         0                1                0       0      0
# 3        14         0                3                1       0      0
# 6        10         0                3                0       1      0
# 7        22         1                1                1       0      0
#
#    Volunteering       GPA  GradeClass result
# ...

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("/content/train (1).csv")

# %%
print(data.head())
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
survived = data['Survived'].to_numpy()

# %%
print("Survived:", np.sum(survived == 1))
print("Not Survived:", np.sum(survived == 0))
# Out:
# Survived: 342
# Not Survived: 549

# %%
print("Average Age:", np.mean(data['Age'].fillna(0).to_numpy()))
# Out:
# Average Age: 23.79929292929293

# %%
import pandas as pd
import numpy as np

# %%
movies = pd.read_csv("/content/movies.csv")
ratings = pd.read_csv("/content/ratings.csv")

# %%
print(movies.head())
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
print(ratings.head())
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
max_rating = ratings['rating'].max()
print("Maximum Rating:", max_rating)
# Out:
# Maximum Rating: 5.0

# %%
min_rating = ratings['rating'].min()
print("Minimum Rating:", min_rating)
# Out:
# Minimum Rating: 0.5

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.array([1,2,3,4,5])
y = np.array([2,1,5,4,10])
plt.plot(x,y)

plt.xlabel("X values")
plt.ylabel("Y values")
plt.title("Simple Line Graph")
plt.show()

# %%
import pandas as np
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("/content/StudentsPerformance.csv")

# %%
math_score = data['math score'].to_numpy()

# %%
print("Average Math Score", np.mean(math_score))
# Out:
# Average Math Score 66.089

# %%
plt.hist(math_score)


plt.title(" math Score Distributon")
plt.xlabel("score")
plt.ylabel("count")
plt.show()

# %%
import pandas as np
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("/content/archive (1).zip")

# %%
print(data.describe())
# Out:
#         open_price   high_price    low_price  close_price        volume
# count  5000.000000  5000.000000  5000.000000  5000.000000  5.000000e+03
# mean    772.708202   811.990270   743.705270   777.440598  2.496821e+07
# std     413.510336   433.521016   405.299947   420.683862  1.441834e+07
# min      50.550000    55.160000    45.420000    50.200000  1.050690e+05
# 25%     414.967500   436.285000   392.562500   406.497500  1.245287e+07
# 50%     771.950000   819.575000   742.910000   787.085000  2.520512e+07
# 75%    1136.812500  1187.797500  1093.585000  1140.910000  3.729874e+07
# max    1499.520000  1549.740000  1448.970000  1499.450000  4.999939e+07

# %%
open_price = data['open_price'].to_numpy()

# %%
print("Average Open Price", np.mean(open_price))
# Out:
# Average Open Price 772.7082019999999

# %%
plt.hist(open_price)


plt.title(" open price Distributon")
plt.ylabel("open price")
plt.xlabel("company")
plt.show()
